# %%
import pandas as pd
import requests as r
from bs4 import BeautifulSoup
import re

# %%
# url ='https://store.ubi.com/fr/all-games?prefn1=productTypeRefinementString&sz=16&format=page-element&prefv1=games&start=16'
url ='https://store.ubi.com/fr/all-games?prefn1=productTypeRefinementString&sz=16&format=page-element&prefv1=games&start=64'

# %%
header= {
'path': '/fr/all-games?prefn1=productTypeRefinementString&sz=16&format=page-element&prefv1=games&start=64',
'scheme':'https',
'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
'cookie':'__cfduid=d75502d5e38ba7e66b95cde9bebc867b81572625411; cqcid=abIbx608U7aQE9fZarr9kvKVbr; prefCountry=fr; dwanonymous_e2d89c436a26bc47381bc6c2fe1f51cc=abIbx608U7aQE9fZarr9kvKVbr; __cq_dnt=0; dw_dnt=0; dwac_decTgiaaiu1Xoaaadq5HbGM599=62Blf52ClEM0pLZE81sOukit2XabUTcFWoI%3D|dw-only|||EUR|false|Europe%2FParis|true; sid=62Blf52ClEM0pLZE81sOukit2XabUTcFWoI; dwsecuretoken_e2d89c436a26bc47381bc6c2fe1f51cc=JO6-fyUt8EvnjoUx_fk-XQRmqVNSIuC7cg==; dwsid=P0FB02CVzX2vb2tYgMrqxZyM_dpmRm47wUnaxZEFJ3E7iyV-I8y1s2ycqisCqFm2sAE87IixV5a3kd3CwTFXJA==',
'upgrade-insecure-requests': '1',
'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36'}

# %%
response = r.get(url, headers=header)

# %%
response
# Out:
# <Response [200]>

# %%
html= r.get(url).content

# %%
soup = BeautifulSoup(html)

# %%
# soup

# %%
id_test = soup.select('ul.search-result-items')

# %%
# id_test

# %%
platforms =[element.get('d') for element in soup.select('span.svg-wrapper svg path')]
# platforms.count('M500 250a250 250 0 0 1-250 250A250 250 0 0 1 0 250 250 250 0 0 1 250 0a250 250 0 0 1 250 250z')

# %%
# platforms.

# %%
# pltfs= {'windows':'M0 431.273l205.258 28.137V263.838H0zm0 0M0 238.93h205.258V40.59L0 68.727zm0 0M227.399 462.638L500 500V263.838H227.399zm0 0M227.399 37.362v201.107H500V0zm0 0',
#         'playstation':'M495.556 352.45c-9.77 12.323-33.697 21.11-33.697 21.11L283.85 437.5v-47.151l131.003-46.677c14.866-5.328 17.149-12.856 5.065-16.81-12.06-3.965-33.901-2.829-48.777 2.522l-87.29 30.742V311.19l5.032-1.702s25.222-8.927 60.692-12.856c35.467-3.907 78.894.532 112.987 13.457 38.422 12.141 42.748 30.037 32.993 42.36zm-194.76-80.293V151.569c0-14.162-2.613-27.197-15.901-30.89-10.177-3.26-16.49 6.188-16.49 20.34V443l-81.44-25.848V57.092c34.627 6.426 85.076 21.623 112.195 30.765 68.97 23.679 92.353 53.151 92.353 119.555 0 64.722-39.952 89.252-90.717 64.745zM37.532 385.419c-39.445-11.108-46.008-34.252-28.03-47.585 16.615-12.311 44.873-21.579 44.873-21.579l116.77-41.52v47.336l-84.03 30.07c-14.844 5.326-17.126 12.867-5.063 16.819 12.07 3.952 33.921 2.828 48.787-2.51l40.306-14.627v42.349c-2.556.454-5.404.909-8.04 1.35-40.319 6.59-83.258 3.84-125.573-10.105z',
#         'unknows':'M177.961 105.732a15.843 15.843 0 0 1-15.843-15.843V30.23a16.09 16.09 0 0 1 31.934 0v59.66a15.843 15.843 0 0 1-16.09 15.842zm153.728 0a15.843 15.843 0 0 1-15.844-15.843V30.23a15.843 15.843 0 0 1 31.687 0v59.66a15.843 15.843 0 0 1-15.843 15.842zM445.313 484.73H54.187A49.51 49.51 0 0 1 .221 430.763V96.325a49.51 49.51 0 0 1 53.966-53.718h391.126a49.51 49.51 0 0 1 54.46 53.718v334.438a49.51 49.51 0 0 1-54.46 53.966zM54.187 74.294c-16.833 0-22.28 5.446-22.28 22.031v334.438c0 16.833 5.447 22.28 22.28 22.28h391.126c16.833 0 22.032-5.447 22.032-22.28V96.325c0-16.585-5.199-22.031-22.032-22.031z',
#         'unknows1':'M388.377 162.42h-41.093v45.797h41.093zM388.377 354.023h-41.093v45.55h41.093zM347.284 308.474h41.093v-45.549h-41.093zM152.71 162.42h-41.092v45.797h41.093zM271.286 162.42h-41.093v45.797h41.093zM152.71 308.474v-45.549h-41.092v45.55zM271.286 354.023h-41.093v45.55h41.093zM271.286 308.474v-45.549h-41.093v45.55zM152.71 354.023h-41.092v45.55h41.093z',
#         'unknows2':'M250 480.301c-126.94 0-230.377-103.362-230.377-230.377C19.623 122.908 122.984 19.547 250 19.547s230.377 103.361 230.377 230.377C480.377 376.939 376.94 480.3 250 480.3z',
#         'unknows3':'M19.927 260.116c0 1.52.228 3.118.228 4.64 1.065 18.1 4.411 35.746 9.583 52.326 30.804 11.409 64.497 17.646 98.95 17.646 145.346 0 264.832-107.773 283.694-247.947-41.68-41.45-99.255-67.082-162.458-67.082-126.94 0-230.377 103.362-230.377 230.377 0 2.586 0 4.944.228 7.53.152.684.152 1.673.152 2.51z',
#         'unknows4':'M358.534 123.821V285.52c0 64.268-39.398 112.488-111.424 112.488-72.026 0-111.424-48.22-111.424-112.488V123.82h58.564v156.982c0 39.398 18.406 61.683 52.86 61.683 34.226 0 52.86-22.285 52.86-61.683V123.821z',
#         'unknows5':'M500 250a250 250 0 0 1-250 250A250 250 0 0 1 0 250 250 250 0 0 1 250 0a250 250 0 0 1 250 250z'
#        }

# %%
# for i in platforms:
#     if i == 'M0 431.273l205.258 28.137V263.838H0zm0 0M0 238.93h205.258V40.59L0 68.727zm0 0M227.399 462.638L500 500V263.838H227.399zm0 0M227.399 37.362v201.107H500V0zm0 0':
        
#     pltfs[j] == [i] in platforms:
#         l.append([i])

# %%
# liste_platforms=[]
# for (i:j) in pltfs:
#     if j == i in platforms:
#         liste_platforms[j]=i
# print(liste_platforms)

# %%
dict_pltfs={}
for i in platforms: 
    if i == 'M0 431.273l205.258 28.137V263.838H0zm0 0M0 238.93h205.258V40.59L0 68.727zm0 0M227.399 462.638L500 500V263.838H227.399zm0 0M227.399 37.362v201.107H500V0zm0 0':
        dict_pltfs.append(i:'windows')
    else:
        i=='M500 250a250 250 0 0 1-250 250A250 250 0 0 1 0 250 250 250 0 0 1 250 0a250 250 0 0 1 250 250z'
        dict_pltfs.append(i :'unknows5')
# Out:
#   File "<ipython-input-787-5d01818c9af8>", line 4
#     dict_pltfs.append(i:'windows')
#                        ^
# SyntaxError: invalid syntax

# %%
platforms
#dico si tel code tel plateform tel code
# Out:
# ['M177.961 105.732a15.843 15.843 0 0 1-15.843-15.843V30.23a16.09 16.09 0 0 1 31.934 0v59.66a15.843 15.843 0 0 1-16.09 15.842zm153.728 0a15.843 15.843 0 0 1-15.844-15.843V30.23a15.843 15.843 0 0 1 31.687 0v59.66a15.843 15.843 0 0 1-15.843 15.842zM445.313 484.73H54.187A49.51 49.51 0 0 1 .221 430.763V96.325a49.51 49.51 0 0 1 53.966-53.718h391.126a49.51 49.51 0 0 1 54.46 53.718v334.438a49.51 49.51 0 0 1-54.46 53.966zM54.187 74.294c-16.833 0-22.28 5.446-22.28 22.031v334.438c0 16.833 5.447 22.28 22.28 22.28h391.126c16.833 0 22.032-5.447 22.032-22.28V96.325c0-16.585-5.199-22.031-22.032-22.031z',
#  'M388.377 162.42h-41.093v45.797h41.093zM388.377 354.023h-41.093v45.55h41.093zM347.284 308.474h41.093v-45.549h-41.093zM152.71 162.42h-41.092v45.797h41.093zM271.286 162.42h-41.093v45.797h41.093zM152.71 308.474v-45.549h-41.092v45.55zM271.286 354.023h-41.093v45.55h41.093zM271.286 308.474v-45.549h-41.093v45.55zM152.71 354.023h-41.092v45.55h41.093z',
# ...

# %%
title =[element.text for element in soup.select('h2.prod-title')]

# %%
title
# Out:
# ['\n\nFar Cry 5\n\n',
#  '\n\nAnno 1800\n\n',
#  "\n\nTom Clancy's Rainbow Six Siege\n\n",
#  "\n\nAssassin's Creed Odyssey\n\n",
#  '\n\nThe Settlers\n\n',
#  '\n\nHeroes of Might & Magic 7\n\n',
#  '\n\nAnno 2205\n\n',
#  "\n\nTom Clancy's Ghost Recon Breakpoint\n\n",
#  "\n\nAssassin's Creed Odyssey\n\n",
#  '\n\nTom Clancy’s Ghost Recon Breakpoint\n\n',
#  '\n\nRayman 2: The Great Escape\n\n',
#  '\n\nSTEEP\n\n',
#  '\n\nAnno 1404\n\n',
#  "\n\nAssassin's Creed\n\n",
#  '\n\nThe Crew 2\n\n',
#  '\n\nMONOPOLY PLUS\n\n']

# %%
rows_t = [row.strip().replace('\n\n','\n') for row in title]
rows_t
# Out:
# ['Far Cry 5',
#  'Anno 1800',
#  "Tom Clancy's Rainbow Six Siege",
#  "Assassin's Creed Odyssey",
#  'The Settlers',
#  'Heroes of Might & Magic 7',
#  'Anno 2205',
#  "Tom Clancy's Ghost Recon Breakpoint",
#  "Assassin's Creed Odyssey",
#  'Tom Clancy’s Ghost Recon Breakpoint',
#  'Rayman 2: The Great Escape',
#  'STEEP',
#  'Anno 1404',
#  "Assassin's Creed",
#  'The Crew 2',
#  'MONOPOLY PLUS']

# %%
date =[element.text for element in soup.select('.release-date.only-on-list')]
date
# Out:
# ['\n\n\n\n\n\nDisponible depuis le\n\n27/03/2018\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n30/07/2019\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n12/02/2019\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n05/10/2018\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n15/11/2018\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n05/08/2016\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n27/10/2016\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n01/10/2019\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n05/10/2018\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n01/10/2019\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n2001\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n30/10/2018\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n08/12/2010\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n2008\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n29/06/2018\n',
#  '\n\n\n\n\n\nDisponible depuis le\n\n26/11/14\n']

# %%
rows_d = [row.strip().replace('\n\n','\n').split('\n')[1] for row in date]
rows_d
# Out:
# ['27/03/2018',
#  '30/07/2019',
#  '12/02/2019',
#  '05/10/2018',
#  '15/11/2018',
#  '05/08/2016',
#  '27/10/2016',
#  '01/10/2019',
#  '05/10/2018',
#  '01/10/2019',
#  '2001',
#  '30/10/2018',
#  '08/12/2010',
#  '2008',
#  '29/06/2018',
#  '26/11/14']

# %%
p_original = [element.text for element in soup.select('span.price-item')]
p_original
# Out:
# ['\n\n59,99 €\n\n',
#  '\n\n94,99 €\n\n',
#  '\n\n99,99 €\n\n',
#  '\n\n159,99 €\n\n',
#  '\n\n39,99 €\n\n',
#  '\n\n44,99 €\n\n',
#  '\n\n49,99 €\n\n',
#  '\n\n179,99 €\n\n',
#  '\n\n99,99 €\n\n',
#  '\n\n99,99 €\n\n',
#  '\n\n5,39 €\n\n',
#  '\n\n39,99 €\n\n',
#  '\n\n14,99 €\n\n',
#  '\n\n9,99 €\n\n',
#  '\n\n59,99 €\n\n',
#  '\n\n14,99 €\n\n']

# %%
rows_original = [row.strip().replace(' €','').replace(',','.') for row in p_original]
rows_original
# Out:
# ['59.99',
#  '94.99',
#  '99.99',
#  '159.99',
#  '39.99',
#  '44.99',
#  '49.99',
#  '179.99',
#  '99.99',
#  '99.99',
#  '5.39',
#  '39.99',
#  '14.99',
#  '9.99',
#  '59.99',
#  '14.99']

# %%
# r_original= [[float(x) for x  in sublist] for sublist in rows_original]
floats = [float(x) for x in rows_original]

# %%
len(rows_original), len(rows_d)
#verifiation de la longueur de mes listes
# Out:
# (16, 16)

# %%
p_promo = [element.text for element in soup.select('span.price-sales')]
p_promo
# Out:
# ['19,80 €',
#  '71,24 €',
#  '49,99 €',
#  '119,99 €',
#  '19,99 €',
#  '11,25 €',
#  '12,50 €',
#  '149,39 €',
#  '40,00 €',
#  '69,99 €',
#  '1,83 €',
#  '14,00 €',
#  '3,75 €',
#  '3,40 €',
#  '15,00 €',
#  '6,00 €']

# %%
rows_promo = [row.strip().replace(' €','').replace(',','.') for row in p_promo]
rows_promo
# Out:
# ['19.80',
#  '71.24',
#  '49.99',
#  '119.99',
#  '19.99',
#  '11.25',
#  '12.50',
#  '149.39',
#  '40.00',
#  '69.99',
#  '1.83',
#  '14.00',
#  '3.75',
#  '3.40',
#  '15.00',
#  '6.00']

# %%
floats_promo = [float(x) for x in rows_promo]
floats_promo
# Out:
# [19.8,
#  71.24,
#  49.99,
#  119.99,
#  19.99,
#  11.25,
#  12.5,
#  149.39,
#  40.0,
#  69.99,
#  1.83,
#  14.0,
#  3.75,
#  3.4,
#  15.0,
#  6.0]

# %%
edition= [element.text for element in soup.select('.card-subtitle h3')]
edition
# Out:
# ['Édition Deluxe',
#  'Édition Gold',
#  'Standard Edition',
#  'Édition Gold',
#  'Édition Standard',
#  'Édition Standard',
#  'Édition Standard',
#  'Édition Standard',
#  'Édition Standard',
#  'Édition Standard',
#  'Édition Collector Bouclier Phoenix',
#  'Édition Ultime',
#  'Édition Standard',
#  'Édition Marching Fire',
#  'Édition Standard',
#  '2019']

# %%
rows_ed = [row.strip().replace(' Edition','').replace('Édition ','') for row in edition]
rows_ed
# Out:
# ['Deluxe',
#  'Gold',
#  'Standard',
#  'Gold',
#  'Standard',
#  'Standard',
#  'Standard',
#  'Standard',
#  'Standard',
#  'Standard',
#  'Collector Bouclier Phoenix',
#  'Ultime',
#  'Standard',
#  'Marching Fire',
#  'Standard',
#  '2019']

# %%
df = pd.DataFrame()
df['date_parution']=[i for i in rows_d]
df['title']=[i for i in rows_t]
df['edition']=[i for i in rows_ed]
df['promotion_price']=[i for i in floats_promo]
df['original_price']=[i for i in floats]
df['%']=round((1-(df['promotion_price']/df['original_price']))*100,2)

# %%
df
# Out:
#    date_parution                                title  \
# 0     27/03/2018                            Far Cry 5
# 1     30/07/2019                            Anno 1800
# 2     12/02/2019       Tom Clancy's Rainbow Six Siege
# 3     05/10/2018             Assassin's Creed Odyssey
# 4     15/11/2018                         The Settlers
# 5     05/08/2016            Heroes of Might & Magic 7
# 6     27/10/2016                            Anno 2205
# 7     01/10/2019  Tom Clancy's Ghost Recon Breakpoint
# 8     05/10/2018             Assassin's Creed Odyssey
# 9     01/10/2019  Tom Clancy’s Ghost Recon Breakpoint
# 10          2001           Rayman 2: The Great Escape
# 11    30/10/2018                                STEEP
# 12    08/12/2010                            Anno 1404
# 13          2008                     Assassin's Creed
# 14    29/06/2018                           The Crew 2
# 15      26/11/14                        MONOPOLY PLUS
#
# ...

# %%
# exclus =( .only_ubisoft_store span ).card-details-wrapper .card-label
#  promotion = .deal-percentage
#  titre du jeux = h2.prod-title
#  edition = .card-subtitle h3
#  date de sortie =  .card-info span.svg-wrapper
#           plateform : (.available-platforms span.svg-wrapper svg path   ou   ) .available-platforms span 
#   prix promo = span.price-sales 
#   prix original = span.price-item
#  date de sortie =  .release-date

# %%
#  games =[element.text for element in soup.select('.card-details-wrapper .card-label, .deal-percentage, h2.prod-title, .card-subtitle h3, .card-info span.svg-wrapper, .available-platforms span, span.price-sales, span.price-item, .release-date')]

# %%
# title =[element.text for element in soup.select('h2.prod-title')]

# %%
# rows = [row.strip().replace('\n\n','\n').split('\n') for row in title]

# %%
# date =[element.text for element in soup.select('.release-date')]

# %%
# rows = [row.strip().replace('\n\n\n\n\n\n','\n').split('\n') for row in date]

# %%
# edition =[element.text for element in soup.select('.card-subtitle h3')]

# %%
# promotion = [element.text for element in soup.select('.deal-percentage')]

# %%
# rows = [row.strip().replace('\n','\n').split('\n') for row in promotion]

# %%
# plateform = [element.text for element in soup.select('.available-platforms span.svg-wrapper svg path')]

# %%
# p_promo = [element.text for element in soup.select('span.price-sales')]

# %%
# rows = [row.strip().replace('€','').split('\n') for row in p_promo]

# %%
# p_original = [element.text for element in soup.select('span.price-item')]

# %%
# rows = [row.strip().replace('\n\n','\n').split('\n') for row in p_original]

# %%
info_plus = [element.text for element in soup.select('.card-details-wrapper')]

# %%
rows = [row.strip().replace('\n\n',' ').split('\n') for row in info_plus]
rows
# Out:
# [["Tom Clancy's Rainbow Six Siege  ",
#   'Le Jeu   ',
#   '-60%   ',
#   'À partir de',
#   '8,00 €  19,99 €     ',
#   "En Savoir Plus        Disponible depuis le 01/12/2015       Gagnez jusqu'à   20"],
#  ['Anno 1800  ',
#   'Édition Standard   ',
#   '-33%   ',
#   'À partir de',
#   '39,99 €  59,99 €     ',
#   "En Savoir Plus        Disponible depuis le 16/04/2019    Gagnez jusqu'à   60"],
#  ["Tom Clancy's Rainbow Six Siege  ",
#   'Édition Deluxe   ',
#   '-60%   ',
#   'À partir de',
#   '12,00 €  29,99 €     ',
#   "En Savoir Plus        Disponible depuis le 12/02/19    Gagnez jusqu'à   30"],
#  ["Tom Clancy's The Division 2  ",
#   'Édition Standard   ',
#   '-65%   ',
#   'À partir de',
#   '21,00 €  59,99 €     ',
#   "En Savoir Plus        Disponible depuis le 15/03/2019       Gagnez jusqu'à   40"],
#  ["Tom Clancy's Ghost Recon Breakpoint  ",
#   'Édition Standard   ',
#   '-20%  ',
#   'Nouveauté  ',
#   'À partir de',
#   '47,99 €  59,99 €     ',
# ...

# %%
# [i[3] for i in rows]

# %%
# for i in rows: 
#     if i[3] == 'Nouveauté':
#         right_index[3]
#     else: 
#         print(i[3])

# %%
# # i[4].replace('À partir de','') for i in rows
# for i[3] in rows:
#     if i[3] == 'Nouveauté':
#         rows[i[3]]=rows[i[3]]+rows[i[4]]
#     else: 
#         print(i[3])

# %%
# [i[4].replace('À partir de','') for i in rows]

# %%
df = pd.DataFrame(rows) 
df
# Out:
#                                         0                              1  \
# 0        Tom Clancy's Rainbow Six Siege                        Le Jeu
# 1                             Anno 1800              Édition Standard
# 2        Tom Clancy's Rainbow Six Siege                Édition Deluxe
# 3           Tom Clancy's The Division 2              Édition Standard
# 4   Tom Clancy's Ghost Recon Breakpoint              Édition Standard
# 5           Tom Clancy's The Division 2              Édition Ultimate
# 6              Assassin's Creed Odyssey              Édition Standard
# 7              Assassin's Creed Odyssey    Édition Numérique Ultimate
# 8   Tom Clancy’s Ghost Recon Breakpoint              Édition Ultimate
# 9              Assassin's Creed Origins                  Édition Gold
# 10          Tom Clancy's The Division 2                  Édition Gold
# 11                            Anno 1800      Édition Deluxe Numérique
# ...
